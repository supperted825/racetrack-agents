# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# For increasing jupyter notebook figure DPI
import matplotlib as MPL
MPL.rcParams['figure.dpi'] = 150

# %% [markdown]
# # PPO Analysis

# %%
ppo_occupancy = pd.read_csv('./logs/ppo_occupancy/Iteration1/log.csv', delimiter=",")

y = ppo_occupancy["Avg Reward"][:130]
x = ppo_occupancy["Total Steps"][:130]

plt.figure()
plt.title("PPO Occupancy Grid, No Vehicles")
xg = plt.xlabel("Simulation Steps")
yg = plt.ylabel("Average Reward")
lg = plt.axhline(y=140, color='r', alpha=0.4, linestyle='dotted', linewidth=1)
plt.plot(x,y)
plt.legend(["Human", "Agent"])

plt.savefig("./videos/graphs/PPOoccuNoVeh.png", dpi=150)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/ky/0pdyyky550xb9lwzcmbsg1040000gn/T/ipykernel_2309/1765089504.py in <module>
# ----> 1 ppo_occupancy = pd.read_csv('./logs/ppo_occupancy/Iteration \1/log.csv', delimiter=",")
#       2
#       3 y = ppo_occupancy["Avg Reward"][:130]
#       4 x = ppo_occupancy["Total Steps"][:130]
#       5
#
# /opt/anaconda3/envs/me5406p2/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
